# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %%
data=pd.read_csv('/content/Uber Drives - .csv')
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.isnull().any()
# Out:
# START_DATE*    False
# END_DATE*       True
# CATEGORY*       True
# START*          True
# STOP*           True
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %%
data['START_DATE*'] = pd.to_datetime(data['START_DATE*'], format="%m/%d/%Y %H:%M")
data['END_DATE*'] = pd.to_datetime(data['END_DATE*'], format="%m/%d/%Y %H:%M")

# %%
hour=[]
day=[]
dayofweek=[]
month=[]
weekday=[]
for x in data['START_DATE*']:
    hour.append(x.hour)
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
data['HOUR']=hour
data['DAY']=day
data['DAY_OF_WEEK']=dayofweek
data['MONTH']=month
data['WEEKDAY']=weekday

# %%
data['CATEGORY*'].value_counts()
# Out:
# CATEGORY*
# Business    647
# Personal      6
# Name: count, dtype: int64

# %%
sns.countplot(x='CATEGORY*',data=data)
# Out:
# <Axes: xlabel='CATEGORY*', ylabel='count'>

# %%
data['MILES*'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
hours = data['START_DATE*'].dt.hour.value_counts()
hours.plot(kind='bar',color='red',figsize=(10,5))
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Number of trips Vs hours')
# Out:
# Text(0.5, 1.0, 'Number of trips Vs hours')

# %%
data['PURPOSE*'].value_counts().plot(kind='bar',figsize=(10,5),color='brown')
# Out:
# <Axes: xlabel='PURPOSE*'>

# %%
data['WEEKDAY'].value_counts().plot(kind='bar',figsize=(10,5),color='blue')
# Out:
# <Axes: xlabel='WEEKDAY'>

# %%
data['DAY'].value_counts().plot(kind='bar',figsize=(10,5),color='green')
# Out:
# <Axes: xlabel='DAY'>

# %%
data['MONTH'].value_counts().plot(kind='bar',figsize=(10,5),color='black')
# Out:
# <Axes: xlabel='MONTH'>

# %%
data['START*'].value_counts().plot(kind='bar',figsize=(25,10),color='blue')
# Out:
# <Axes: xlabel='START*'>

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git remote add origin https://github.com/Dhruvmahapure/data-analytics.git

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !mv /content/ Uber Data Analysis.ipynb /content/data-analytics.git/
# Out:
# mv: target '/content/data-analytics.git/' is not a directory

# %%
# %cd /content/data-analytics.git
# Out:
# [Errno 2] No such file or directory: '/content/data-analytics.git'
# /content

# %%
# !git add  Uber Data Analysis.ipynb
# Out:
# fatal: pathspec 'Uber' did not match any files
